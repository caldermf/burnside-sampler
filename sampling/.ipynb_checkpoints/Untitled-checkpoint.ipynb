# %%
p = 5
F = GF(p)
A = Matrix(F, [[1,1,0],[0,1,0],[0,0,1]])
J, P = A.jordan_form(transformation=True)
J  # the Jordan form
P  # the change-of-basis matrix

partition = []
i = 0
while i < J.nrows():
    size = 1
    lam = J[i,i]
    while i+size < J.nrows() and J[i+size-1,i+size] == 1:
        size += 1
    partition.append(size)
    i += size

partition  # list of Jordan block sizes
# Out:
# [2, 1]

# %%
print(green_eval([2,1], 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(green_eval([Integer(2),Integer(1)], Integer(5)))
#
# Cell In[12], line 446, in green_eval(lambda_parts, q)
#     444 mu = Partition([Integer(1)] * n)
#     445 calc = Calculator()
# --> 446 poly = calc.green_polynomial_Q(lam, mu)
#     447 # Evaluate polynomial at q
#     448 result = Integer(0)
#
# Cell In[12], line 336, in Calculator.green_polynomial_Q(self, lam, mu)
#     334 def green_polynomial_Q(self, lam: Partition, mu: Partition) -> Polynomial:
#     335     """Green polynomial with Q-variable (involution of X-version)"""
# --> 336     polynomial = self.green_polynomial_X(lam, mu)
#     337     return polynomial.involution()
#
# Cell In[12], line 375, in Calculator.green_polynomial_X(self, lam, mu)
#     373 remaining_sum = n - lam.element_at(Integer(0)) - tau.sum
#     374 for rho in generate_partitions(remaining_sum):
# --> 375     current_polynomial = self.z_inverse(rho)
#     376     recursive_partition = tau.concat(rho)
#     377     recursive = self.green_polynomial_X(lam.delete_first_row(), recursive_partition)
#
# Cell In[12], line 326, in Calculator.z_inverse(self, partition)
#     324 for part in partition.parts:
#     325     basic_polynomial = self.get_basic_polynomial(part)
# --> 326     result = result * basic_polynomial
#     328 z_lambda = self.centralizer_size(partition)
#     329 result = result.scalar_multiply(Fraction(Integer(1), z_lambda))
#
# Cell In[12], line 169, in Polynomial.__mul__(self, other)
#     167     for d2, c2 in other.coef.items():
#     168         dd = d1 + d2
# --> 169         res[dd] = res.get(dd, Fraction(Integer(0))) + c1 * c2
#     170 return Polynomial(res)
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/fractions.py:665, in Fraction._operator_fallbacks.<locals>.forward(a, b)
#     663 def forward(a, b):
#     664     if isinstance(b, Fraction):
# --> 665         return monomorphic_operator(a, b)
#     666     elif isinstance(b, int):
#     667         return monomorphic_operator(a, Fraction(b))
#
# File /private/var/tmp/sage-10.7-current/local/lib/python3.13/fractions.py:796, in Fraction._mul(a, b)
#     794 na, da = a._numerator, a._denominator
#     795 nb, db = b._numerator, b._denominator
# --> 796 g1 = math.gcd(na, db)
#     797 if g1 > 1:
#     798     na //= g1
#
# TypeError: 'method' object cannot be interpreted as an integer
