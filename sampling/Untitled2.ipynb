# %%
from green import green_eval
print(green_eval([2,1], 3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from green import green_eval
# ----> 2 print(green_eval([Integer(2),Integer(1)], Integer(3)))
#
# File ~/Documents/Sage Notebooks/Persi/sampling/green.py:444, in green_eval(lambda_parts, q)
#     439 """
#     440 Compute the Green polynomial G_{(1^n)}^lambda(q) where n = sum(lambda_parts),
#     441 and evaluate it at q.
#     442 """
#     443 lam = Partition(lambda_parts)
# --> 444 n = lam.sum()
#     445 mu = Partition([1] * n)
#     446 calc = Calculator()
#
# TypeError: 'int' object is not callable

# %%
p = 5
F = GF(p)
A = Matrix(F, [[1,1,0],[0,1,0],[0,0,1]])
J, P = A.jordan_form(transformation=True)
J  # the Jordan form
P  # the change-of-basis matrix

partition = []
i = 0
while i < J.nrows():
    size = 1
    lam = J[i,i]
    while i+size < J.nrows() and J[i+size-1,i+size] == 1:
        size += 1
    partition.append(size)
    i += size

partition  # list of Jordan block sizes
# Out:
# [2, 1]

# %%
print(type(green([2,1])))
# Out:
# <class 'green.Polynomial'>
